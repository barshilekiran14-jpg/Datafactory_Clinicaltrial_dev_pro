-- %%
drop table clintrail_dev.clintrail_bronze.dm;
drop table clintrail_dev.clintrail_bronze.sv;
drop table clintrail_dev.clintrail_bronze.vs;
drop table clintrail_dev.clintrail_bronze.lb;
drop table clintrail_dev.clintrail_bronze.eg;
drop table clintrail_dev.clintrail_bronze.ec;
drop table clintrail_dev.clintrail_bronze.cm;
drop table clintrail_dev.clintrail_bronze.ds;
drop table clintrail_dev.clintrail_bronze.ta;
drop table clintrail_dev.clintrail_bronze.ts;
